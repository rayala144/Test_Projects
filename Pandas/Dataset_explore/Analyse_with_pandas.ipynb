# %%
import pandas as pd
nba = pd.read_csv('nba_all_elo.csv')
laptops = pd.read_csv('laptops.csv')
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option("display.max.columns", None)
# nba.head(5)

# %%
pd.set_option("display.precision", 2)
nba.info()  # gets columns with their data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# min      1091.64    1085.77      10.15       0.00    1091.64    1085.77
# 25%      1417.24    1416.99      34.10      93.00    1417.24    1416.99
# 50%      1500.95    1500.95      42.11     103.00    1500.95    1500.95
# 75%      1576.06    1576.29      49.64     112.00    1576.06    1576.29
# max      1853.10    1853.10      71.11     186.00    1853.10    1853.10
#
#         forecast
# count  126314.00
# mean        0.50
# std         0.22
# min         0.02
# 25%         0.33
# 50%         0.50
# 75%         0.67
# max         0.98

# %%
nba['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
nba['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# Steamrollers     168
# Packers           72
# Redskins          65
# Rebels            63
# Waterloo          62
# Denver            62
# Falcons           60
# Jets              60
# Ironmen           60
# Huskies           60
# Name: fran_id, dtype: int64

# %%
nba.loc[nba['fran_id'] == 'Lakers', 'team_id'].value_counts() # locating a particular set of cells
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
nba['date_played'] = pd.to_datetime(nba['date_game'])

# %%
mnl_datePlayed = nba.loc[nba['team_id'] == 'MNL', 'date_played']
min_date = nba.loc[nba['team_id'] == 'MNL', 'date_played'].min()
max_date = nba.loc[nba['team_id'] == 'MNL', 'date_played'].max()
# print(f'{min_date}, {max_date}')
mnl_datePlayed.aggregate((min, max))
# Out:
# min   1948-11-04
# max   1960-03-26
# Name: date_played, dtype: datetime64[ns]

# %%
nba.loc[nba['team_id'] == 'BOS', 'game_id'].count() # total no of games played
# Out:
# 5997

# %%
nba.loc[nba['team_id'] == 'BOS', 'pts'].sum()
# Out:
# 626484

# %% [markdown]
# Understanding data structures of Pandas dataframe

# %%
numbers = pd.Series([21355, 37732, 251326, 43627])
numbers.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
import numpy as np
revenues = np.array([21355, 37732, 251326, 43627])
cities = np.array(['New York', 'Delhi', 'Hyderabad', 'Bangalore'])
city_revenues = pd.Series(
    revenues, cities # panda series
)
city_revenues
# Out:
# New York      21355
# Delhi         37732
# Hyderabad    251326
# Bangalore     43627
# dtype: int32

# %%
city_employee_count = pd.Series({'New York': 10, 'Delhi': 16, 'Hyderabad' : 13, 'Bangalore' : 14}) 
# pandas series using dictionary
city_employee_count
# Out:
# New York     10
# Delhi        16
# Hyderabad    13
# Bangalore    14
# dtype: int64

# %%
city_data = pd.DataFrame({
    'Revenue':city_revenues,
    'Employee_count': city_employee_count
})
# city_data.index = [i+1 for i in range(len(city_data))]
city_data
# Out:
#            Revenue  Employee_count
# New York     21355              10
# Delhi        37732              16
# Hyderabad   251326              13
# Bangalore    43627              14

# %%
city_data.axes
# Out:
# [Index(['New York', 'Delhi', 'Hyderabad', 'Bangalore'], dtype='object'),
#  Index(['Revenue', 'Employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['New York', 'Delhi', 'Hyderabad', 'Bangalore'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['Revenue', 'Employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['Revenue', 'Employee_count'], dtype='object')

# %%
'New York' in cities
# Out:
# True

# %%
nba.axes
'points' in nba.keys()
# Out:
# False

# %% [markdown]
# Label index and positional index

# %%
print(city_revenues[2], city_revenues['Hyderabad'])
# Out:
# 251326 251326

# %%
colors = pd.Series(["red", "purple", "blue", "green", "yellow"], index=[1, 2, 3, 5, 8] )
colors.loc[3] # returns blue (Label index)
# Out:
# 'blue'

# %%
colors.iloc[3] # returns green (Positional index)
# Out:
# 'green'

# %%
city_data.iloc[0]
# Out:
# Revenue           21355
# Employee_count       10
# Name: New York, dtype: int64

# %%
nba.iloc[-2]
# Out:
# gameorder                      63157
# game_id                 201506170CLE
# lg_id                            NBA
# _iscopy                            0
# year_id                         2015
# date_game                  6/16/2015
# seasongame                       102
# is_playoffs                        1
# team_id                          CLE
# fran_id                    Cavaliers
# pts                               97
# elo_i                        1700.74
# elo_n                        1692.09
# win_equiv                      59.29
# opp_id                           GSW
# opp_fran                    Warriors
# opp_pts                          105
# opp_elo_i                    1813.63
# opp_elo_n                    1822.29
# game_location                      H
# game_result                        L
# forecast                        0.48
# notes                            NaN
# date_played      2015-06-16 00:00:00
# Name: 126312, dtype: object

# %%
city_data.loc['New York':'Delhi', 'Employee_count']
# Out:
# New York    10
# Delhi       16
# Name: Employee_count, dtype: int64

# %%
nba.loc[5555:5559, ['fran_id', 'opp_fran', 'pts']]
# Out:
#       fran_id  opp_fran  pts
# 5555  Pistons  Warriors   83
# 5556  Celtics    Knicks   95
# 5557   Knicks   Celtics   74
# 5558    Kings    Sixers   81
# 5559   Sixers     Kings   86

# %%
this_decade = nba[nba['year_id'] > 2010]
this_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015  06-11-2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# 113657           1            0     BOS    Celtics   88  1625.10  1629.30
# 113658           1            0     HOU    Rockets  110  1504.20  1502.60
# 113659           1            0     LAL     Lakers  112  1647.60  1649.20
# 113660           1            0     PHO       Suns   92  1643.02  1630.62
# ...            ...          ...     ...        ...  ...      ...      ...
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 113656      45.14    BOS       Celtics       88    1625.10    1629.30
# 113657      53.75    MIA          Heat       80    1547.36    1543.16
# 113658      40.90    LAL        Lakers      112    1647.60    1649.20
# 113659      55.61    HOU       Rockets      110    1504.20    1502.60
# 113660      53.88    POR  Trailblazers      106    1552.81    1565.22
# ...           ...    ...           ...      ...        ...        ...
# 126309      60.31    GSW      Warriors      103    1790.96    1809.98
# 126310      68.01    CLE     Cavaliers       91    1704.39    1700.74
# 126311      60.01    GSW      Warriors      104    1809.98    1813.63
# 126312      59.29    GSW      Warriors      105    1813.63    1822.29
# 126313      68.52    CLE     Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes date_played
# 113656             A           L      0.26   NaN  2010-10-26
# 113657             H           W      0.74   NaN  2010-10-26
# 113658             A           L      0.20   NaN  2010-10-26
# 113659             H           W      0.80   NaN  2010-10-26
# 113660             A           L      0.49   NaN  2010-10-26
# ...              ...         ...       ...   ...         ...
# 126309             H           L      0.55   NaN  2015-06-11
# 126310             H           W      0.77   NaN  2015-06-14
# 126311             A           L      0.23   NaN  2015-06-14
# 126312             H           L      0.48   NaN  2015-06-16
# 126313             A           W      0.52   NaN  2015-06-16
#
# [12658 rows x 24 columns]

# %%
games_with_notes = nba[nba['notes'].notnull()] # also notna()
games_with_notes.shape
# Out:
# (5424, 24)

# %%
team_end_ers = nba[nba['fran_id'].str.endswith('ers')]
team_end_ers.shape
# Out:
# (27797, 24)

# %%
nba[
    (nba["_iscopy"] == 0)  &
    (nba["pts"] > 100) &
    (nba['opp_pts'] > 100) &
    (nba['team_id'] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949   2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  01-10-1953          32
# 4909       2455  195301140BLB   NBA        0     1953   1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  03-11-1953          66
# 5825       2913  195402220BLB   NBA        0     1954   2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
#      opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 1726   Lakers      115    1637.99    1640.49             H           L
# 4890  Celtics      105    1591.14    1563.17             H           W
# 4909   Lakers      112    1665.44    1668.91             H           L
# 5208   Knicks      113    1649.15    1651.44             H           L
# 5825  Celtics      111    1591.49    1593.27             H           L
#
#       forecast            notes date_played
# 1726      0.34              NaN  1949-02-26
# 4890      0.28              NaN  1953-01-10
# 4909      0.22              NaN  1953-01-14
# 5208      0.18     at Boston MA  1953-03-11
# 5825      0.25  at Worcester MA  1954-02-22

# %%
points = nba['pts']
type(points)
points.sum()
# Out:
# 12976235

# %%
warr_games = nba[
    nba['fran_id'] == 'Warriors'
]
warr_games[
    warr_games['pts'] <= warr_games['opp_pts']
]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 66             34  194611190GSW   NBA        0     1947  11/19/1946
# 78             40  194611210GSW   NBA        0     1947  11/21/1946
# 116            59  194611280GSW   NBA        0     1947  11/28/1946
# 123            62  194611300NYK   NBA        1     1947  11/30/1946
# 162            82  194612080CLR   NBA        1     1947  12-08-1946
# ...           ...           ...   ...      ...      ...         ...
# 126244      63123  201505050GSW   NBA        0     2015  05-05-2015
# 126254      63128  201505090MEM   NBA        1     2015  05-09-2015
# 126296      63149  201505250HOU   NBA        1     2015   5/25/2015
# 126305      63153  201506070GSW   NBA        0     2015  06-07-2015
# 126306      63154  201506090CLE   NBA        1     2015  06-09-2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 66               3            0     PHW  Warriors   63  1308.66  1301.04
# 78               4            0     PHW  Warriors   63  1301.04  1294.76
# 116              6            0     PHW  Warriors   55  1300.63  1284.44
# 123              7            0     PHW  Warriors   60  1284.44  1281.17
# 162             11            0     PHW  Warriors   66  1313.63  1308.40
# ...            ...          ...     ...       ...  ...      ...      ...
# 126244          88            1     GSW  Warriors   90  1789.29  1771.11
# 126254          89            1     GSW  Warriors   89  1771.11  1758.90
# 126296          96            1     GSW  Warriors  115  1813.45  1797.89
# 126305          99            1     GSW  Warriors   93  1806.20  1797.50
# 126306         100            1     GSW  Warriors   91  1797.50  1790.96
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 66          41.11    STB    Bombers       66    1315.33    1322.95
# 78          40.45    CHS      Stags       65    1323.82    1330.09
# 116         39.37    DTF    Falcons       68    1317.76    1333.95
# 123         39.03    NYK     Knicks       64    1339.62    1342.89
# 162         41.88    CLR     Rebels       72    1310.46    1315.69
# ...           ...    ...        ...      ...        ...        ...
# 126244      65.31    MEM  Grizzlies       97    1606.40    1624.58
# 126254      64.46    MEM  Grizzlies       99    1624.58    1636.79
# 126296      67.05    HOU    Rockets      128    1643.43    1658.99
# 126305      67.03    CLE  Cavaliers       95    1708.17    1716.87
# 126306      66.62    CLE  Cavaliers       96    1716.87    1723.41
#
#        game_location game_result  forecast notes date_played
# 66                 H           L      0.63   NaN  1946-11-19
# 78                 H           L      0.61   NaN  1946-11-21
# 116                H           L      0.62   NaN  1946-11-28
# 123                A           L      0.29   NaN  1946-11-30
# 162                A           L      0.36   NaN  1946-12-08
# ...              ...         ...       ...   ...         ...
# 126244             H           L      0.84   NaN  2015-05-05
# 126254             A           L      0.57   NaN  2015-05-09
# 126296             A           L      0.60   NaN  2015-05-25
# 126305             H           L      0.76   NaN  2015-06-07
# 126306             A           L      0.47   NaN  2015-06-09
#
# [3011 rows x 24 columns]
